# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append('..')

# %%
import tensorflow as tf

from src.models import UnetEffNetV2

# %%
model = UnetEffNetV2(weights=None)
model.summary()
# Out:
# >>>> No pretrained available, model will be randomly initialized
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 256, 256, 24) 648         input_3[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 256, 256, 24) 96          stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_swish (Activation)         (None, 256, 256, 24) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# ...
